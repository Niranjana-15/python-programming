# %%
#print colors in set1 but not in set2
a=set(input("enter the colors: ").split(","))
b=set(input("enter colors: ").split(","))
colors=a-b
print("the colors are: ",colors)
# Out:
# enter the colors:  red,yellow,pink
# enter colors:  yellow,white,orange
# the colors are:  {'red', 'pink'}

# %%
#union of colors from 2 set
a=set(input("enter the colors: ").split(","))
b=set(input("enter colors: ").split(","))
colors=a|b #represet union
print("the colors are: ",colors)
# Out:
# enter the colors:  red,green,yellow
# enter colors:  white,orange,brown
# the colors are:  {'white', 'green', 'brown', 'yellow', 'red', 'orange'}
