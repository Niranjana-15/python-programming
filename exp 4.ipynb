# %%
#list of colors seperated by commas
colors=input("Enter colours seperated by commas:")
colors=colors.split(",")
print("First color:",colors[0])
print("last color:",colors[-1])
# Out:
# Enter colours seperated by commas: red,blue,green,yellow
# First color: red
# last color: yellow

# %%
#program to accept a file from the user
filename=input("enter file name:")
extension=filename.split(".")[-1]
print("Extension:",extension)
# Out:
# enter file name: exp4.py
# Extension: py

# %%
numbers=input("enter comma-seperated numbers:")
num_list=numbers.split(",")
num_list=[int(x)for x in num_list]
print("list:",num_list)
print("sum",sum(num_list))
# Out:
# enter comma-seperated numbers: 2,4,1,123,67
# list: [2, 4, 1, 123, 67]
# sum 197
