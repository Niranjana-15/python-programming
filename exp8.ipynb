# %%
#accept 5 students roll no and sort them in ascending and descending order
print("Enter 5 roll number of students:")
roll=input().split(",")
print("Enter 5 names of students:")
name=input().split(",")
student=dict(zip(map(int,roll),name))
ascending=dict(sorted(student.items()))
descending=dict(sorted(student.items(),reverse=True))
print("The dictionary is:",student)
print("ascending order",ascending)
print("descending order",descending)
# Out:
# Enter 5 roll number of students:
#  1,2,3,4,5
# Enter 5 names of students:
#  niranjana,nafeeza,jodika,rasha,anamika
# The dictionary is: {1: 'niranjana', 2: 'nafeeza', 3: 'jodika', 4: 'rasha', 5: 'anamika'}
# ascending order {1: 'niranjana', 2: 'nafeeza', 3: 'jodika', 4: 'rasha', 5: 'anamika'}
# descending order {5: 'anamika', 4: 'rasha', 3: 'jodika', 2: 'nafeeza', 1: 'niranjana'}

# %%
#accept 3 dictionaries and merge them
print("Enter 5 roll number of students:")
roll=input().split(",")
print("enter 5 names of students:")
name=input().split(",")
dic1=dict(zip(map(int,roll),name))
print("The dictionary is:",dic1)
print("Enter 3 roll number of students:")
roll=input().split(",")
print("enter 3 names of students:")
name=input().split(",")
dic2=dict(zip(map(int,roll),name))
print("The dictionary is:",dic2)
dic1.update(dic2)
print("The merged dictionary is:",dic1)
# Out:
# Enter 5 roll number of students:
#  1,2,3,4,5
# enter 5 names of students:
#  niranjana,rasha,nafeeza,raniya,jodika
# The dictionary is: {1: 'niranjana', 2: 'rasha', 3: 'nafeeza', 4: 'raniya', 5: 'jodika'}
# Enter 3 roll number of students:
#  6,7,8
# enter 3 names of students:
#  hisam,safeer,rashil
# The dictionary is: {6: 'hisam', 7: 'safeer', 8: 'rashil'}
# The merged dictionary is: {1: 'niranjana', 2: 'rasha', 3: 'nafeeza', 4: 'raniya', 5: 'jodika', 6: 'hisam', 7: 'safeer', 8: 'rashil'}
