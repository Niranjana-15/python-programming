# %%
#swap first two character of two string
s=input("Enter a string:")
new_string=s[-1]+s[1:-1]+s[0]
print("New string:",new_string)
# Out:
# Enter a string: python
# New string: nythop

# %%
s=input("Enter a string:")
new_string=s[1:-1]+s[0]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: tudens

# %%
s=input("Enter a string:")
new_string=s[-1]+s[0]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: ts

# %%
s=input("Enter a string:")
new_string=s[-1]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: t

# %%
s=input("Enter a string:")
new_string=s[-1]+s[1:-1]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: ttuden

# %%
s=input("Enter a string:")
new_string=s[2]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: u

# %%
s=input("Enter a string:")
new_string=s[-2]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: n

# %%
s=input("Enter a string:")
new_string="s[2]+s[-2]"
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: s[2]+s[-2]

# %%
s=input("Enter a string:")
new_string=s[-2]+s[2]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: nu

# %%
s=input("Enter a string:")
new_string=s[2]+s[-2]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: un

# %%
s=input("Enter a string:")
new_string=s[:2]+s[-2:]
print("New string:",new_string)
# Out:
# Enter a string: student
# New string: stnt
